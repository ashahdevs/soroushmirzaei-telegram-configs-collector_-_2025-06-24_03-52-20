# %% [markdown]
# <a href="https://colab.research.google.com/github/ashahdevs/soroushmirzaei-telegram-configs-collector_-_2025-06-24_03-52-20/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ashahdevs/soroushmirzaei-telegram-configs-collector_-_2025-06-24_03-52-20.git
# Out:
# Cloning into 'soroushmirzaei-telegram-configs-collector_-_2025-06-24_03-52-20'...
# remote: Enumerating objects: 1155, done.
# remote: Total 1155 (delta 0), reused 0 (delta 0), pack-reused 1155 (from 1)
# Receiving objects: 100% (1155/1155), 32.92 MiB | 17.63 MiB/s, done.
# Resolving deltas: 100% (535/535), done.

# %%
# %cd soroushmirzaei-telegram-configs-collector_-_2025-06-24_03-52-20
# Out:
# /content/soroushmirzaei-telegram-configs-collector_-_2025-06-24_03-52-20

# %%
# !pip install -r requirements
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 75.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.6/244.6 kB 24.4 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=0314c1ae720a609b9a93687bd90a6b006a9710fbb6e1a20ad7e73dc8d5c55d2c
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# ...

# %%
# !python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# MODIFIED CONFIG: vless://f6f6693f-365c-4ec0-bd1e-ebe9406ba595@62.60.210.118:5149?security=none&type=tcp&headerType=http#🔒 VL-TCP-NONE 🇮🇷 IR-62.60.210.118:5149
#
# MODIFIED CONFIG: vless://f6f6693f-365c-4ec0-bd1e-ebe9406ba595@62.60.212.23:5149?security=none&type=tcp&headerType=http#🔒 VL-TCP-NONE 🇮🇷 IR-62.60.212.23:5149
#
# MODIFIED CONFIG: vless://f6f6693f-365c-4ec0-bd1e-ebe9406ba595@5.160.35.77:5149?security=none&type=tcp&headerType=http#🔒 VL-TCP-NONE 🇮🇷 IR-5.160.35.77:5149
#
# MODIFIED CONFIG: vless://f6f6693f-365c-4ec0-bd1e-ebe9406ba595@5.160.35.79:5149?security=none&type=tcp&headerType=http#🔒 VL-TCP-NONE 🇮🇷 IR-5.160.35.79:5149
#
# MODIFIED CONFIG: vless://f6f6693f-365c-4ec0-bd1e-ebe9406ba595@185.173.107.63:5149?security=none&type=tcp&headerType=http#🔒 VL-TCP-NONE 🇮🇷 IR-185.173.107.63:5149
#
# ...

# %%
# !git config --global user.name "ashahdevs"
# !git config --global user.email "arabshahistudio@gmail.com"
# !git config --global user.password "Maman@@@1372"

# %%
# !git remote -v
# Out:
# origin	https://github.com/ashahdevs/soroushmirzaei-telegram-configs-collector_-_2025-06-24_03-52-20.git (fetch)
# origin	https://github.com/ashahdevs/soroushmirzaei-telegram-configs-collector_-_2025-06-24_03-52-20.git (push)

# %%
# !git add .
# !git commit -m "Updated"
# !git push
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
